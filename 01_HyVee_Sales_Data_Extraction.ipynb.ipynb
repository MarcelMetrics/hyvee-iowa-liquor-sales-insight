# %%
# !pip install --upgrade pip
# !pip install pandas
# !pip install sodapy
# Out:
# Requirement already satisfied: pandas in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: sodapy in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marcel zhang\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (2023.11.17)

# %%
import pandas as pd
from sodapy import Socrata
import json
from datetime import datetime, timedelta

# %%
with open('config.json') as f:
  config = json.load(f)

AppToken = config['app_token']
UserName = config['user_name']
Password = config["password"]

# %%
client = Socrata("data.iowa.gov",
                 AppToken,
                 username = UserName,
                 password = Password,
                 timeout=30)

# %%
col_selected = 'invoice_line_no, date, store, name, city, zipcode, county, category, category_name, vendor_no, vendor_name, itemno, im_desc, state_bottle_cost, state_bottle_retail, sale_bottles, sale_dollars'
col_list = ['invoice_line_no', 'date', 'store', 'name', 'city', 'zipcode', 'county', 'category', 'category_name', 'itemno', 'im_desc', 'state_bottle_cost', 'state_bottle_retail', 'sale_bottles', 'sale_dollars']
len(col_list)
# Out:
# 15

# %%
start_year = 2021
current_year = datetime.now().year

for year in range(start_year, current_year + 1):
    start_date = f"{year}-01-01T00:00:00.000"
    end_date = f"{year + 1}-01-01T00:00:00.000"

    total_rows = []  # Store all rows for the year
    limit = 5000  # Set the limit per page
    offset = 0  
    more_data = True  

    while more_data:
        results = client.get("m3tr-qhgy",
                             select=col_selected, 
                             where=f"LOWER(name) LIKE '%hy-vee%' AND date >= '{start_date}' AND date < '{end_date}'", 
                             limit=limit, 
                             offset=offset)
        total_rows.extend(results)  

        if len(results) < limit:
            more_data = False
        else:
            offset += limit 

    df = pd.DataFrame.from_records(total_rows)
    print(f"Rows for {year}: {df.shape[0]}")  

    # Save to CSV
    df.to_csv(f'data/hyvee_{year}.csv', index=False)
    print(f"Dataset for {year} is saved.")
# Out:
# Rows for 2019: 762568
# Rows for 2020: 814746
# Rows for 2021: 772734
# Rows for 2022: 733503
# Rows for 2023: 643450

# %%
df.head()
# Out:
#    invoice_line_no                     date store  \
# 0  INV-54554300002  2023-01-02T00:00:00.000  2699
# 1  INV-54555100014  2023-01-02T00:00:00.000  2636
# 2  INV-54554200012  2023-01-02T00:00:00.000  2666
# 3  INV-54555100017  2023-01-02T00:00:00.000  2636
# 4  INV-54554900003  2023-01-02T00:00:00.000  2633
#
#                                   name        city zipcode county category  \
# 0           HY-VEE C-STORE #2 - ANKENY      ANKENY   50023   POLK  1031100
# 1    HY-VEE WINE AND SPIRITS / HUBBELL  DES MOINES   50317   POLK  1012100
# 2  HY-VEE FOOD STORE #2 / STATE ANKENY      ANKENY   50023   POLK  1011200
# 3    HY-VEE WINE AND SPIRITS / HUBBELL  DES MOINES   50317   POLK  1031100
# 4         HY-VEE #3 / BDI / DES MOINES  DES MOINES   50320   POLK  1011200
#
#                category_name vendor_no           vendor_name itemno  \
# 0            AMERICAN VODKAS       301  FIFTH GENERATION INC  38176
# 1          CANADIAN WHISKIES       260       DIAGEO AMERICAS  11297
# 2  STRAIGHT BOURBON WHISKIES       260       DIAGEO AMERICAS  17086
# 3            AMERICAN VODKAS       421  SAZERAC COMPANY  INC  35317
# 4  STRAIGHT BOURBON WHISKIES       619       CAMPARI AMERICA  22157
#
#                 im_desc state_bottle_cost state_bottle_retail sale_bottles  \
# 0  TITOS HANDMADE VODKA             10.00               15.00           24
# 1           CROWN ROYAL             19.99               29.99           12
# 2       BULLEIT BOURBON             17.49               26.24           12
# 3          BARTON VODKA              3.97                5.96           12
# 4       WILD TURKEY 101             17.50               26.25           17
#
#   sale_dollars
# 0       360.00
# 1       359.88
# 2       314.88
# 3        71.52
# 4       446.25
